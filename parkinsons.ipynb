# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the excel file

pk_df = pd.read_csv('parkinsons.csv')

pd.set_option('display.max_columns', None)
pk_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233
# 3           0.00009   0.00502   0.00698     0.01505       0.05492
# 4           0.00011   0.00655   0.00908     0.01966       0.06425
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# ...

# %%
pk_df.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# ...

# %%
pk_df.shape
# Out:
# (195, 24)

# %%
pk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
pk_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pk_df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# histogram to understand the distibution
pk_df.hist(figsize=(10,6))
plt.tight_layout()
plt.show()

# %%
pk_df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Define numerical columns for outlier detection
outlier_columns = [ 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
       'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
       'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
       'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA',
       'spread1', 'spread2', 'D2', 'PPE'
    ]

# Number of plots per row
plots_per_row = 4
total_plots = len(outlier_columns)
rows = (total_plots + plots_per_row - 1) // plots_per_row

# Set figure size
plt.figure(figsize=(10, rows * 4))

# Plot boxplots
for i, col in enumerate(outlier_columns, 1):
    plt.subplot(rows, plots_per_row, i)
    plt.boxplot(pk_df[col].dropna(), patch_artist=True,
                boxprops=dict(facecolor='skyblue'),
                medianprops=dict(color='red'),
                whiskerprops=dict(color='black'),
                capprops=dict(color='black'),
                flierprops=dict(markerfacecolor='orange', marker='o', markersize=5))
    plt.title(col)
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
 # List of features with high outliers based on your analysis
features_to_cap = [
    'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
       'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
       'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
       'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR',
       'spread1', 'spread2', 'D2', 'PPE'
]

def cap_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap values outside the bounds
    pk_df[col] = pk_df[col].clip(lower=lower_bound, upper=upper_bound)
    return df

# Apply capping only to specified features
for feature in features_to_cap:
    if feature in pk_df.columns:
        print(f"Capping outliers in: {feature}")
        pk_df = cap_outliers_iqr(pk_df, feature)
    else:
        print(f"Feature '{feature}' not found in DataFrame.")
# Out:
# Capping outliers in: MDVP:Fhi(Hz)
# Capping outliers in: MDVP:Flo(Hz)
# Capping outliers in: MDVP:Jitter(%)
# Capping outliers in: MDVP:Jitter(Abs)
# Capping outliers in: MDVP:RAP
# Capping outliers in: MDVP:PPQ
# Capping outliers in: Jitter:DDP
# Capping outliers in: MDVP:Shimmer
# Capping outliers in: MDVP:Shimmer(dB)
# Capping outliers in: Shimmer:APQ3
# Capping outliers in: Shimmer:APQ5
# Capping outliers in: MDVP:APQ
# Capping outliers in: Shimmer:DDA
# Capping outliers in: NHR
# Capping outliers in: HNR
# Capping outliers in: spread1
# Capping outliers in: spread2
# Capping outliers in: D2
# Capping outliers in: PPE

# %%
import matplotlib.pyplot as plt

# Define numerical columns for outlier detection
outlier_columns = [ 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
       'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
       'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
       'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA',
       'spread1', 'spread2', 'D2', 'PPE'
    ]

# Number of plots per row
plots_per_row = 4
total_plots = len(outlier_columns)
rows = (total_plots + plots_per_row - 1) // plots_per_row

# Set figure size
plt.figure(figsize=(10, rows * 4))

# Plot boxplots
for i, col in enumerate(outlier_columns, 1):
    plt.subplot(rows, plots_per_row, i)
    plt.boxplot(pk_df[col].dropna(), patch_artist=True,
                boxprops=dict(facecolor='skyblue'),
                medianprops=dict(color='red'),
                whiskerprops=dict(color='black'),
                capprops=dict(color='black'),
                flierprops=dict(markerfacecolor='orange', marker='o', markersize=5))
    plt.title(col)
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from imblearn.pipeline import Pipeline

# %% [markdown]
# # Parkinsons

# %%
x = pk_df.drop(columns=['name','status'], axis=1)
y = pk_df['status']

# %%
#splitting the data for training and testing 

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, stratify=y, random_state=42)

# %%
x_train.value_counts()
y_train.value_counts()
# Out:
# status
# 1    118
# 0     38
# Name: count, dtype: int64

# %%
smote = SMOTE()
x_res, y_res = smote.fit_resample(x_train, y_train)

# %%
# creating a pipeline

pipe = Pipeline([ 
    ('scaler', StandardScaler()), 
    ('rfc', RandomForestClassifier(random_state=42))
])

pipe.fit(x_res, y_res)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rfc', RandomForestClassifier(random_state=42))])

# %%
y_pred = pipe.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print('Model accuracy score : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39
#
# [[ 8  2]
#  [ 1 28]]
# Model accuracy score : 0.9231

# %%
y_proba = pipe.predict_proba(x_test)[:, 1]

# Try a lower threshold like 0.35 or 0.4
threshold = 0.5
y_pred_thresh = (y_proba >= threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
print(confusion_matrix(y_test, y_pred_thresh))
print(classification_report(y_test, y_pred_thresh))
print('Model accuracy score : {0:0.4f}'. format(accuracy_score(y_test, y_pred_thresh)))
# Out:
# [[ 8  2]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39
#
# Model accuracy score : 0.9231

# %%
for threshold in [0.42, 0.45, 0.48]:
    y_pred_thresh = (y_proba >= threshold).astype(int)
    print(f"Threshold: {threshold}")
    print(confusion_matrix(y_test, y_pred_thresh))
    print(classification_report(y_test, y_pred_thresh))
    print('Model accuracy score : {0:0.4f}'. format(accuracy_score(y_test, y_pred_thresh)))
    print()
# Out:
# Threshold: 0.42
# [[ 8  2]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39
#
# Model accuracy score : 0.9231
#
# Threshold: 0.45
# [[ 8  2]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39
#
# Model accuracy score : 0.9231
#
# Threshold: 0.48
# [[ 8  2]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
# ...

# %%
import pickle

with open('parkinsons_model.pkl', 'wb') as f:
    pickle.dump(pipe, f)
